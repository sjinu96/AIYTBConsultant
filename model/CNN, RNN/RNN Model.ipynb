# %%
! jt -t chesterish # chesterish 테마로 변경합니다.

# %%
import pandas as pd
import os

def load(
    filter_size: '60, 90, 180', 
    target_size: '1, 7, 30, 180', 
    stride: '1, 2, 3',
    drop_suffix: '각 변수 끝에 붙은 번호를 제거할지 여부'=True,
    path='/Users/Namin/Documents/CAP/CapstoneUOS/Data/data_variants',) -> (pd.DataFrame, pd.DataFrame):
    
    print(f'Setting: filter_size({filter_size})\ttarget_size({target_size})\tstride({stride})\tdrop_suffix({drop_suffix})')
    X_name = f'fs({filter_size})_ts({target_size})_st({stride}).csv'
    y_name = f'fs({filter_size})_ts({target_size})_st({stride})_label.csv'
    
    print('Load feature data...', end='\t')
    X = pd.read_csv(os.path.join(path, X_name))
    print('loaded!')
    print('Load label data...', end='\t')
    y = pd.read_csv(os.path.join(path, y_name))
    print('loaded!')
    
    if drop_suffix:
        X.columns = list(map(lambda x: x.split('.')[0], X.columns.tolist()))
        y.columns = list(map(lambda x: x.split('.')[0], y.columns.tolist()))

    return X, y

# %%
filter_size = 90
target_size = 90
stride = 1
X, y = load(filter_size, target_size, stride)
# Out:
# Setting: filter_size(90)	target_size(90)	stride(1)	drop_suffix(True)
# Load feature data...	loaded!
# Load label data...	loaded!

# %%
features = ['n_hashtage', 'video_num', 'no_upload_interval',
            'duration', 'video_n_view', 'n_dislike', 'n_like', 'n_comment',
            'view_diff',
            'sub_diff']
target_features = ['sub_diff']

X = X[features]
y = y[target_features]
y = pd.DataFrame(y.iloc[:,-1], columns=['sub_diff'])

# %%
# Split

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

random_state = 42
test_size = 0.2

X_trn, X_test, y_trn, y_test = train_test_split(
    X, y, 
    shuffle=True, 
    test_size=test_size, 
    random_state=random_state
) 

X_train, X_valid, y_train, y_valid = train_test_split(
    X_trn, y_trn, 
    shuffle=True, 
    test_size=test_size, 
    random_state=random_state
) 

### 스케일링 필요 시 다음을 진행(타깃에 대한 스케일링은 진행되지 않음)
scaler = MinMaxScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train), columns=X_train.columns)
X_valid = pd.DataFrame(scaler.transform(X_valid), columns=X_valid.columns)
X_test = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns)

# %%
print("X_train's shape: ", X_train.shape) 
print("y_train's shape: ", y_train.shape) 
print("X_valid's shape: ", X_valid.shape)
print("y_valid's shape: ", y_valid.shape)
print("X_test's shape: ", X_test.shape)
print("y_test's shape: ", y_test.shape)
# Out:
# X_train's shape:  (65849, 900)
# y_train's shape:  (65849, 1)
# X_valid's shape:  (16463, 900)
# y_valid's shape:  (16463, 1)
# X_test's shape:  (20579, 900)
# y_test's shape:  (20579, 1)

# %%
# 데이터 구성 살피기
import matplotlib.pyplot as plt
plt.style.use('ggplot')

h = 3 # graph's height(length)

for n in range(10): # 1부터 x_train.shape[0]까지
    fig = plt.figure(figsize=(h*len(set(X_train.columns.tolist())), h))
    for i, train_var in enumerate(set(X_train.columns.tolist())):
        plt.subplot(1, len(set(X_train.columns.tolist())), i+1)
        plt.plot(X_train[train_var].iloc[n].values)
        plt.title(str(train_var))

    fig = plt.figure(figsize=(h*len(set(y_train.columns.tolist())), h))
    for i, label_var in enumerate(set(y_train.columns.tolist())):
        plt.subplot(1, len(set(y_train.columns.tolist())), i+1)
        plt.plot(y_train[label_var].iloc[n], marker='o')
        plt.title("GOAL: " + str(label_var))
        
    plt.show()

# %%
n1 = 10 # number of train features
n2 = 1 # number of target features

x_train_copy = X_train.fillna(0).values.reshape(X_train.shape[0], n1, -1)
y_train_copy = y_train.fillna(0).values.reshape(y_train.shape[0], n2, -1)
x_val_copy = X_valid.fillna(0).values.reshape(X_valid.shape[0], n1, -1)
y_val_copy = y_valid.fillna(0).values.reshape(y_valid.shape[0], n2, -1)
x_test_copy = X_test.fillna(0).values.reshape(X_test.shape[0], n1, -1)
y_test_copy = y_test.fillna(0).values.reshape(y_test.shape[0], n2, -1)

# %%
print("x_train_copy's shape: ", x_train_copy.shape) 
print("y_train_copy's shape: ", y_train_copy.shape) 
print("x_val_copy's shape: ", x_val_copy.shape)
print("y_val_copy's shape: ", y_val_copy.shape)
print("x_test_copy's shape: ", x_test_copy.shape)
print("y_test_copy's shape: ", y_test_copy.shape)
# Out:
# x_train_copy's shape:  (65849, 10, 90)
# y_train_copy's shape:  (65849, 1, 1)
# x_val_copy's shape:  (16463, 10, 90)
# y_val_copy's shape:  (16463, 1, 1)
# x_test_copy's shape:  (20579, 10, 90)
# y_test_copy's shape:  (20579, 1, 1)

# %%
# 모델 만들기
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, TimeDistributed, Conv1D, MaxPooling1D, Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam, RMSprop

filters = len(features)
output_num = len(target_features)

model = Sequential()
model.add(TimeDistributed(Dense(128, activation='softmax'),
          input_shape=(x_train_copy.shape[-2:])))
model.add(LSTM(units=64, return_sequences=True))
#model.add(TimeDistributed(Dense(16, activation='softmax')))
#model.add(TimeDistributed(Dense(4, activation='softmax')))
#model.add(TimeDistributed(Dense(1, activation='softmax')))
model.add(Flatten())
model.add(Dense(64))
model.add(Dense(16))
model.add(Dense(4))
model.add(Dense(output_num))

def rmse(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

model.compile(loss=['mae'],
              metrics=[tf.keras.metrics.RootMeanSquaredError()],
              optimizer=Adam(lr=0.0001))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed (TimeDistri (None, 10, 128)           11648
# _________________________________________________________________
# lstm (LSTM)                  (None, 10, 64)            49408
# _________________________________________________________________
# flatten (Flatten)            (None, 640)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                41024
# _________________________________________________________________
# dense_2 (Dense)              (None, 16)                1040
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 68
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 103,193
# Trainable params: 103,193
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 기록하기
import time

filename='rnn_{}_{}_{}.h5'.format(filter_size, target_size, stride)

callback_list = [tf.keras.callbacks.ModelCheckpoint(filepath='Checkpoint/{}'.format(filename),
                                                    monitor='val_loss',
                                                    verbose=1,
                                                    save_best_only=True,
                                                    mode='min'),
                 #tf.keras.callbacks.TensorBoard(log_dir='TensorBoard/rnn/{}'.format(time.asctime())),
                 tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                                  patience=5),
                 #tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',
                 #                                     factor=0.1,
                 #                                     min_lr=1e-4, 
                 #                                     patience=0)
                ]

EPOCHS = 100
BATCH_SIZE = 32 

history2 = model.fit(x_train_copy, y_train_copy,
                     epochs=EPOCHS,
                     batch_size=BATCH_SIZE,
                     validation_data=(x_val_copy, y_val_copy),
                     callbacks=callback_list)
# Out:
# Train on 65849 samples, validate on 16463 samples
# Epoch 1/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 331.2932 - root_mean_squared_error: 1873.4664
# Epoch 00001: val_loss improved from inf to 353.15658, saving model to Checkpoint/rnn_90_90_1.h5
# 65849/65849 [==============================] - 144s 2ms/sample - loss: 331.4505 - root_mean_squared_error: 1873.5514 - val_loss: 353.1566 - val_root_mean_squared_error: 3135.1296
# Epoch 2/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 331.3215 - root_mean_squared_error: 1873.3678
# Epoch 00002: val_loss improved from 353.15658 to 353.15202, saving model to Checkpoint/rnn_90_90_1.h5
# 65849/65849 [==============================] - 154s 2ms/sample - loss: 331.4426 - root_mean_squared_error: 1873.5441 - val_loss: 353.1520 - val_root_mean_squared_error: 3135.1211
# Epoch 3/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 331.3714 - root_mean_squared_error: 1873.4696
# Epoch 00003: val_loss did not improve from 353.15202
# 65849/65849 [==============================] - 159s 2ms/sample - loss: 331.4326 - root_mean_squared_error: 1873.5239 - val_loss: 353.1782 - val_root_mean_squared_error: 3134.9666
# Epoch 4/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 331.3203 - root_mean_squared_error: 1873.3795
# Epoch 00004: val_loss improved from 353.15202 to 353.14777, saving model to Checkpoint/rnn_90_90_1.h5
# 65849/65849 [==============================] - 149s 2ms/sample - loss: 331.4274 - root_mean_squared_error: 1873.4459 - val_loss: 353.1478 - val_root_mean_squared_error: 3135.0803
# Epoch 5/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 331.3656 - root_mean_squared_error: 1873.6281
# Epoch 00005: val_loss improved from 353.14777 to 353.14240, saving model to Checkpoint/rnn_90_90_1.h5
# 65849/65849 [==============================] - 141s 2ms/sample - loss: 331.4198 - root_mean_squared_error: 1873.4497 - val_loss: 353.1424 - val_root_mean_squared_error: 3135.0591
# Epoch 6/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 331.3218 - root_mean_squared_error: 1873.3423
# Epoch 00006: val_loss improved from 353.14240 to 353.12932, saving model to Checkpoint/rnn_90_90_1.h5
# 65849/65849 [==============================] - 149s 2ms/sample - loss: 331.4084 - root_mean_squared_error: 1873.4189 - val_loss: 353.1293 - val_root_mean_squared_error: 3135.0247
# Epoch 7/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 331.4436 - root_mean_squared_error: 1873.6602
# Epoch 00007: val_loss improved from 353.12932 to 353.09443, saving model to Checkpoint/rnn_90_90_1.h5
# 65849/65849 [==============================] - 153s 2ms/sample - loss: 331.3824 - root_mean_squared_error: 1873.3260 - val_loss: 353.0944 - val_root_mean_squared_error: 3134.9631
# Epoch 8/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 331.3720 - root_mean_squared_error: 1873.4388
# Epoch 00008: val_loss improved from 353.09443 to 352.98572, saving model to Checkpoint/rnn_90_90_1.h5
# 65849/65849 [==============================] - 153s 2ms/sample - loss: 331.3113 - root_mean_squared_error: 1873.0934 - val_loss: 352.9857 - val_root_mean_squared_error: 3134.7437
# Epoch 9/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 330.9689 - root_mean_squared_error: 1872.2881
# Epoch 00009: val_loss improved from 352.98572 to 352.26741, saving model to Checkpoint/rnn_90_90_1.h5
# 65849/65849 [==============================] - 158s 2ms/sample - loss: 330.9736 - root_mean_squared_error: 1872.0878 - val_loss: 352.2674 - val_root_mean_squared_error: 3133.5830
# Epoch 10/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 329.6755 - root_mean_squared_error: 1867.5254
# Epoch 00010: val_loss improved from 352.26741 to 350.74817, saving model to Checkpoint/rnn_90_90_1.h5
# 65849/65849 [==============================] - 153s 2ms/sample - loss: 329.5910 - root_mean_squared_error: 1867.1804 - val_loss: 350.7482 - val_root_mean_squared_error: 3129.7744
# Epoch 11/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 326.3430 - root_mean_squared_error: 1856.4702
# Epoch 00011: val_loss improved from 350.74817 to 347.64901, saving model to Checkpoint/rnn_90_90_1.h5
# 65849/65849 [==============================] - 145s 2ms/sample - loss: 326.2718 - root_mean_squared_error: 1856.1243 - val_loss: 347.6490 - val_root_mean_squared_error: 3117.9194
# Epoch 12/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 317.5322 - root_mean_squared_error: 1830.6385
# Epoch 00012: val_loss improved from 347.64901 to 334.77385, saving model to Checkpoint/rnn_90_90_1.h5
# 65849/65849 [==============================] - 136s 2ms/sample - loss: 317.5353 - root_mean_squared_error: 1830.3823 - val_loss: 334.7739 - val_root_mean_squared_error: 3098.0132
# Epoch 13/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 305.9776 - root_mean_squared_error: 1794.8640 ETA: 1s - l
# Epoch 00013: val_loss improved from 334.77385 to 323.15728, saving model to Checkpoint/rnn_90_90_1.h5
# 65849/65849 [==============================] - 148s 2ms/sample - loss: 305.9610 - root_mean_squared_error: 1794.5730 - val_loss: 323.1573 - val_root_mean_squared_error: 3081.8306
# Epoch 14/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 301.3224 - root_mean_squared_error: 1773.4478
# Epoch 00014: val_loss improved from 323.15728 to 322.94888, saving model to Checkpoint/rnn_90_90_1.h5
# 65849/65849 [==============================] - 135s 2ms/sample - loss: 301.6645 - root_mean_squared_error: 1774.7993 - val_loss: 322.9489 - val_root_mean_squared_error: 3076.9866
# Epoch 15/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 300.7662 - root_mean_squared_error: 1769.7643
# Epoch 00015: val_loss improved from 322.94888 to 322.43049, saving model to Checkpoint/rnn_90_90_1.h5
# 65849/65849 [==============================] - 133s 2ms/sample - loss: 300.6774 - root_mean_squared_error: 1769.4297 - val_loss: 322.4305 - val_root_mean_squared_error: 3072.6934
# Epoch 16/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 300.4578 - root_mean_squared_error: 1766.0388
# Epoch 00016: val_loss did not improve from 322.43049
# 65849/65849 [==============================] - 127s 2ms/sample - loss: 300.4250 - root_mean_squared_error: 1765.7238 - val_loss: 323.4362 - val_root_mean_squared_error: 3073.1958
# Epoch 17/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 300.1045 - root_mean_squared_error: 1765.3337
# Epoch 00017: val_loss improved from 322.43049 to 321.54263, saving model to Checkpoint/rnn_90_90_1.h5
# 65849/65849 [==============================] - 140s 2ms/sample - loss: 300.0310 - root_mean_squared_error: 1765.0023 - val_loss: 321.5426 - val_root_mean_squared_error: 3072.0823
# Epoch 18/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 300.0127 - root_mean_squared_error: 1764.2982
# Epoch 00018: val_loss improved from 321.54263 to 321.22849, saving model to Checkpoint/rnn_90_90_1.h5
# 65849/65849 [==============================] - 145s 2ms/sample - loss: 299.9343 - root_mean_squared_error: 1763.9657 - val_loss: 321.2285 - val_root_mean_squared_error: 3071.5857
# Epoch 19/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 299.6743 - root_mean_squared_error: 1762.4996
# Epoch 00019: val_loss improved from 321.22849 to 320.82428, saving model to Checkpoint/rnn_90_90_1.h5
# 65849/65849 [==============================] - 134s 2ms/sample - loss: 299.7674 - root_mean_squared_error: 1762.4852 - val_loss: 320.8243 - val_root_mean_squared_error: 3071.8152
# Epoch 20/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 299.6322 - root_mean_squared_error: 1761.6656
# Epoch 00020: val_loss did not improve from 320.82428
# 65849/65849 [==============================] - 132s 2ms/sample - loss: 299.6087 - root_mean_squared_error: 1761.3608 - val_loss: 321.0902 - val_root_mean_squared_error: 3072.0894
# Epoch 21/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 299.6055 - root_mean_squared_error: 1761.3159
# Epoch 00021: val_loss did not improve from 320.82428
# 65849/65849 [==============================] - 137s 2ms/sample - loss: 299.5488 - root_mean_squared_error: 1760.9899 - val_loss: 321.5489 - val_root_mean_squared_error: 3070.2566
# Epoch 22/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 299.3362 - root_mean_squared_error: 1760.6248
# Epoch 00022: val_loss did not improve from 320.82428
# 65849/65849 [==============================] - 138s 2ms/sample - loss: 299.2922 - root_mean_squared_error: 1760.3168 - val_loss: 322.4782 - val_root_mean_squared_error: 3067.4775
# Epoch 23/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 299.2359 - root_mean_squared_error: 1758.5043
# Epoch 00023: val_loss improved from 320.82428 to 320.51477, saving model to Checkpoint/rnn_90_90_1.h5
# 65849/65849 [==============================] - 146s 2ms/sample - loss: 299.1995 - root_mean_squared_error: 1758.1913 - val_loss: 320.5148 - val_root_mean_squared_error: 3068.3904
# Epoch 24/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 299.1349 - root_mean_squared_error: 1757.6312
# Epoch 00024: val_loss improved from 320.51477 to 319.98135, saving model to Checkpoint/rnn_90_90_1.h5
# 65849/65849 [==============================] - 185s 3ms/sample - loss: 299.0943 - root_mean_squared_error: 1757.3093 - val_loss: 319.9814 - val_root_mean_squared_error: 3069.6382
# Epoch 25/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 298.9601 - root_mean_squared_error: 1757.1447
# Epoch 00025: val_loss did not improve from 319.98135
# 65849/65849 [==============================] - 162s 2ms/sample - loss: 298.8878 - root_mean_squared_error: 1756.8146 - val_loss: 320.1290 - val_root_mean_squared_error: 3069.3455
# Epoch 26/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 298.7522 - root_mean_squared_error: 1756.3798
# Epoch 00026: val_loss improved from 319.98135 to 319.71724, saving model to Checkpoint/rnn_90_90_1.h5
# 65849/65849 [==============================] - 186s 3ms/sample - loss: 298.7600 - root_mean_squared_error: 1756.1354 - val_loss: 319.7172 - val_root_mean_squared_error: 3066.2859
# Epoch 27/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 298.5843 - root_mean_squared_error: 1754.9081
# Epoch 00027: val_loss did not improve from 319.71724
# 65849/65849 [==============================] - 152s 2ms/sample - loss: 298.5900 - root_mean_squared_error: 1754.6804 - val_loss: 321.0993 - val_root_mean_squared_error: 3067.3604
# Epoch 28/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 298.2979 - root_mean_squared_error: 1753.3654
# Epoch 00028: val_loss did not improve from 319.71724
# 65849/65849 [==============================] - 131s 2ms/sample - loss: 298.5494 - root_mean_squared_error: 1754.2534 - val_loss: 321.7160 - val_root_mean_squared_error: 3066.7417
# Epoch 29/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 298.3743 - root_mean_squared_error: 1753.2639
# Epoch 00029: val_loss improved from 319.71724 to 319.52479, saving model to Checkpoint/rnn_90_90_1.h5
# 65849/65849 [==============================] - 130s 2ms/sample - loss: 298.4348 - root_mean_squared_error: 1753.0911 - val_loss: 319.5248 - val_root_mean_squared_error: 3067.1101
# Epoch 30/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 298.3915 - root_mean_squared_error: 1753.1281
# Epoch 00030: val_loss did not improve from 319.52479
# 65849/65849 [==============================] - 129s 2ms/sample - loss: 298.3281 - root_mean_squared_error: 1752.8015 - val_loss: 319.6399 - val_root_mean_squared_error: 3066.3418
# Epoch 31/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 298.2936 - root_mean_squared_error: 1752.4612
# Epoch 00031: val_loss improved from 319.52479 to 319.16977, saving model to Checkpoint/rnn_90_90_1.h5
# 65849/65849 [==============================] - 129s 2ms/sample - loss: 298.2373 - root_mean_squared_error: 1752.1367 - val_loss: 319.1698 - val_root_mean_squared_error: 3064.2751
# Epoch 32/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 297.9710 - root_mean_squared_error: 1749.7925
# Epoch 00032: val_loss did not improve from 319.16977
# 65849/65849 [==============================] - 123s 2ms/sample - loss: 298.2205 - root_mean_squared_error: 1751.0312 - val_loss: 319.2824 - val_root_mean_squared_error: 3064.0376
# Epoch 33/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 298.1293 - root_mean_squared_error: 1750.6415
# Epoch 00033: val_loss improved from 319.16977 to 319.13058, saving model to Checkpoint/rnn_90_90_1.h5
# 65849/65849 [==============================] - 129s 2ms/sample - loss: 298.1185 - root_mean_squared_error: 1750.3541 - val_loss: 319.1306 - val_root_mean_squared_error: 3062.6912
# Epoch 34/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 298.1570 - root_mean_squared_error: 1748.9247
# Epoch 00034: val_loss did not improve from 319.13058
# 65849/65849 [==============================] - 136s 2ms/sample - loss: 298.1475 - root_mean_squared_error: 1748.7169 - val_loss: 319.6749 - val_root_mean_squared_error: 3065.7305
# Epoch 35/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 298.0029 - root_mean_squared_error: 1749.8005
# Epoch 00035: val_loss improved from 319.13058 to 318.71682, saving model to Checkpoint/rnn_90_90_1.h5
# 65849/65849 [==============================] - 127s 2ms/sample - loss: 297.9918 - root_mean_squared_error: 1749.5128 - val_loss: 318.7168 - val_root_mean_squared_error: 3063.3052
# Epoch 36/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 297.9140 - root_mean_squared_error: 1748.1910
# Epoch 00036: val_loss improved from 318.71682 to 318.57428, saving model to Checkpoint/rnn_90_90_1.h5
# 65849/65849 [==============================] - 123s 2ms/sample - loss: 297.8698 - root_mean_squared_error: 1747.8717 - val_loss: 318.5743 - val_root_mean_squared_error: 3061.8545
# Epoch 37/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 297.8789 - root_mean_squared_error: 1746.9547
# Epoch 00037: val_loss improved from 318.57428 to 318.40922, saving model to Checkpoint/rnn_90_90_1.h5
# 65849/65849 [==============================] - 124s 2ms/sample - loss: 297.8219 - root_mean_squared_error: 1746.6309 - val_loss: 318.4092 - val_root_mean_squared_error: 3062.4688
# Epoch 38/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 297.7168 - root_mean_squared_error: 1747.0889
# Epoch 00038: val_loss did not improve from 318.40922
# 65849/65849 [==============================] - 125s 2ms/sample - loss: 297.7067 - root_mean_squared_error: 1746.8104 - val_loss: 318.9858 - val_root_mean_squared_error: 3059.0229
# Epoch 39/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 297.7016 - root_mean_squared_error: 1744.5925
# Epoch 00039: val_loss improved from 318.40922 to 318.30956, saving model to Checkpoint/rnn_90_90_1.h5
# 65849/65849 [==============================] - 125s 2ms/sample - loss: 297.6399 - root_mean_squared_error: 1744.2770 - val_loss: 318.3096 - val_root_mean_squared_error: 3061.4597
# Epoch 40/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 297.3890 - root_mean_squared_error: 1744.3132
# Epoch 00040: val_loss did not improve from 318.30956
# 65849/65849 [==============================] - 126s 2ms/sample - loss: 297.4095 - root_mean_squared_error: 1744.0458 - val_loss: 319.1009 - val_root_mean_squared_error: 3060.4143
# Epoch 41/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 297.4850 - root_mean_squared_error: 1743.4886
# Epoch 00041: val_loss did not improve from 318.30956
# 65849/65849 [==============================] - 126s 2ms/sample - loss: 297.4305 - root_mean_squared_error: 1743.1688 - val_loss: 320.5162 - val_root_mean_squared_error: 3060.5212
# Epoch 42/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 297.1153 - root_mean_squared_error: 1740.4470
# Epoch 00042: val_loss did not improve from 318.30956
# 65849/65849 [==============================] - 126s 2ms/sample - loss: 297.4147 - root_mean_squared_error: 1742.1681 - val_loss: 320.0244 - val_root_mean_squared_error: 3058.1562
# Epoch 43/100
# 65792/65849 [============================>.] - ETA: 0s - loss: 297.3543 - root_mean_squared_error: 1741.2390
# Epoch 00043: val_loss did not improve from 318.30956
# 65849/65849 [==============================] - 114s 2ms/sample - loss: 297.3184 - root_mean_squared_error: 1740.6194 - val_loss: 318.3292 - val_root_mean_squared_error: 3058.6313
# Epoch 44/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 297.1717 - root_mean_squared_error: 1740.8054
# Epoch 00044: val_loss improved from 318.30956 to 317.95530, saving model to Checkpoint/rnn_90_90_1.h5
# 65849/65849 [==============================] - 114s 2ms/sample - loss: 297.1885 - root_mean_squared_error: 1740.5662 - val_loss: 317.9553 - val_root_mean_squared_error: 3056.1650
# Epoch 45/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 296.8850 - root_mean_squared_error: 1738.5785
# Epoch 00045: val_loss did not improve from 317.95530
# 65849/65849 [==============================] - 114s 2ms/sample - loss: 297.0332 - root_mean_squared_error: 1738.5083 - val_loss: 320.0910 - val_root_mean_squared_error: 3055.1453
# Epoch 46/100
# 65792/65849 [============================>.] - ETA: 0s - loss: 297.1037 - root_mean_squared_error: 1738.3005
# Epoch 00046: val_loss improved from 317.95530 to 317.53297, saving model to Checkpoint/rnn_90_90_1.h5
# 65849/65849 [==============================] - 114s 2ms/sample - loss: 296.9620 - root_mean_squared_error: 1737.5637 - val_loss: 317.5330 - val_root_mean_squared_error: 3056.1160
# Epoch 47/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 296.8385 - root_mean_squared_error: 1736.3358
# Epoch 00047: val_loss improved from 317.53297 to 317.11178, saving model to Checkpoint/rnn_90_90_1.h5
# 65849/65849 [==============================] - 114s 2ms/sample - loss: 296.8359 - root_mean_squared_error: 1736.0480 - val_loss: 317.1118 - val_root_mean_squared_error: 3055.7607
# Epoch 48/100
# 65792/65849 [============================>.] - ETA: 0s - loss: 296.8022 - root_mean_squared_error: 1736.6603
# Epoch 00048: val_loss improved from 317.11178 to 316.94638, saving model to Checkpoint/rnn_90_90_1.h5
# 65849/65849 [==============================] - 114s 2ms/sample - loss: 296.7902 - root_mean_squared_error: 1736.0272 - val_loss: 316.9464 - val_root_mean_squared_error: 3052.7808
# Epoch 49/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 296.7026 - root_mean_squared_error: 1734.2415
# Epoch 00049: val_loss did not improve from 316.94638
# 65849/65849 [==============================] - 143s 2ms/sample - loss: 296.6635 - root_mean_squared_error: 1733.9353 - val_loss: 317.6524 - val_root_mean_squared_error: 3052.8303
# Epoch 50/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 296.5679 - root_mean_squared_error: 1732.7859
# Epoch 00050: val_loss improved from 316.94638 to 316.54019, saving model to Checkpoint/rnn_90_90_1.h5
# 65849/65849 [==============================] - 123s 2ms/sample - loss: 296.6189 - root_mean_squared_error: 1732.6324 - val_loss: 316.5402 - val_root_mean_squared_error: 3055.4421
# Epoch 51/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 296.5945 - root_mean_squared_error: 1733.2192
# Epoch 00051: val_loss did not improve from 316.54019
# 65849/65849 [==============================] - 119s 2ms/sample - loss: 296.5505 - root_mean_squared_error: 1732.9116 - val_loss: 318.2180 - val_root_mean_squared_error: 3052.1172
# Epoch 52/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 296.1324 - root_mean_squared_error: 1730.9633
# Epoch 00052: val_loss improved from 316.54019 to 315.93580, saving model to Checkpoint/rnn_90_90_1.h5
# 65849/65849 [==============================] - 122s 2ms/sample - loss: 296.2969 - root_mean_squared_error: 1731.2043 - val_loss: 315.9358 - val_root_mean_squared_error: 3051.1753
# Epoch 53/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 296.1809 - root_mean_squared_error: 1729.7653
# Epoch 00053: val_loss improved from 315.93580 to 315.78618, saving model to Checkpoint/rnn_90_90_1.h5
# 65849/65849 [==============================] - 120s 2ms/sample - loss: 296.2609 - root_mean_squared_error: 1729.6451 - val_loss: 315.7862 - val_root_mean_squared_error: 3049.9011
# Epoch 54/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 296.2109 - root_mean_squared_error: 1728.9645
# Epoch 00054: val_loss did not improve from 315.78618
# 65849/65849 [==============================] - 131s 2ms/sample - loss: 296.1431 - root_mean_squared_error: 1728.6439 - val_loss: 316.7172 - val_root_mean_squared_error: 3048.7173
# Epoch 55/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 295.8992 - root_mean_squared_error: 1726.8057
# Epoch 00055: val_loss improved from 315.78618 to 315.38975, saving model to Checkpoint/rnn_90_90_1.h5
# 65849/65849 [==============================] - 128s 2ms/sample - loss: 295.8581 - root_mean_squared_error: 1726.4939 - val_loss: 315.3898 - val_root_mean_squared_error: 3050.9099
# Epoch 56/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 295.8689 - root_mean_squared_error: 1727.2902
# Epoch 00056: val_loss did not improve from 315.38975
# 65849/65849 [==============================] - 131s 2ms/sample - loss: 295.8359 - root_mean_squared_error: 1726.9871 - val_loss: 315.7487 - val_root_mean_squared_error: 3049.1157
# Epoch 57/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 295.8234 - root_mean_squared_error: 1726.6047
# Epoch 00057: val_loss improved from 315.38975 to 315.03156, saving model to Checkpoint/rnn_90_90_1.h5
# 65849/65849 [==============================] - 145s 2ms/sample - loss: 295.7636 - root_mean_squared_error: 1726.2864 - val_loss: 315.0316 - val_root_mean_squared_error: 3049.6655
# Epoch 58/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 295.6492 - root_mean_squared_error: 1726.7618
# Epoch 00058: val_loss improved from 315.03156 to 314.88582, saving model to Checkpoint/rnn_90_90_1.h5
# 65849/65849 [==============================] - 128s 2ms/sample - loss: 295.6872 - root_mean_squared_error: 1726.5679 - val_loss: 314.8858 - val_root_mean_squared_error: 3048.9055
# Epoch 59/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 295.5922 - root_mean_squared_error: 1725.8912
# Epoch 00059: val_loss did not improve from 314.88582
# 65849/65849 [==============================] - 119s 2ms/sample - loss: 295.5999 - root_mean_squared_error: 1725.6697 - val_loss: 316.8851 - val_root_mean_squared_error: 3050.6113
# Epoch 60/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 295.5235 - root_mean_squared_error: 1725.9276
# Epoch 00060: val_loss did not improve from 314.88582
# 65849/65849 [==============================] - 132s 2ms/sample - loss: 295.4763 - root_mean_squared_error: 1725.6136 - val_loss: 317.8552 - val_root_mean_squared_error: 3049.1228
# Epoch 61/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 295.5093 - root_mean_squared_error: 1726.6042
# Epoch 00061: val_loss improved from 314.88582 to 314.83042, saving model to Checkpoint/rnn_90_90_1.h5
# 65849/65849 [==============================] - 127s 2ms/sample - loss: 295.5191 - root_mean_squared_error: 1726.3391 - val_loss: 314.8304 - val_root_mean_squared_error: 3048.1499
# Epoch 62/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 295.5502 - root_mean_squared_error: 1726.5272
# Epoch 00062: val_loss did not improve from 314.83042
# 65849/65849 [==============================] - 127s 2ms/sample - loss: 295.5071 - root_mean_squared_error: 1726.2140 - val_loss: 315.0728 - val_root_mean_squared_error: 3045.8137
# Epoch 63/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 295.4113 - root_mean_squared_error: 1724.8322
# Epoch 00063: val_loss did not improve from 314.83042
# 65849/65849 [==============================] - 125s 2ms/sample - loss: 295.4939 - root_mean_squared_error: 1724.8141 - val_loss: 315.0076 - val_root_mean_squared_error: 3047.4084
# Epoch 64/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 295.4573 - root_mean_squared_error: 1725.2593
# Epoch 00064: val_loss did not improve from 314.83042
# 65849/65849 [==============================] - 136s 2ms/sample - loss: 295.4207 - root_mean_squared_error: 1724.9512 - val_loss: 315.8298 - val_root_mean_squared_error: 3046.9087
# Epoch 65/100
# 65792/65849 [============================>.] - ETA: 0s - loss: 295.3085 - root_mean_squared_error: 1724.3857
# Epoch 00065: val_loss improved from 314.83042 to 314.59568, saving model to Checkpoint/rnn_90_90_1.h5
# 65849/65849 [==============================] - 117s 2ms/sample - loss: 295.3618 - root_mean_squared_error: 1724.6060 - val_loss: 314.5957 - val_root_mean_squared_error: 3046.5977
# Epoch 66/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 295.3789 - root_mean_squared_error: 1724.6498
# Epoch 00066: val_loss did not improve from 314.59568
# 65849/65849 [==============================] - 119s 2ms/sample - loss: 295.3322 - root_mean_squared_error: 1724.3407 - val_loss: 314.7413 - val_root_mean_squared_error: 3046.3838
# Epoch 67/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 295.2442 - root_mean_squared_error: 1723.8810
# Epoch 00067: val_loss improved from 314.59568 to 314.52050, saving model to Checkpoint/rnn_90_90_1.h5
# 65849/65849 [==============================] - 117s 2ms/sample - loss: 295.2345 - root_mean_squared_error: 1723.5991 - val_loss: 314.5205 - val_root_mean_squared_error: 3046.8516
# Epoch 68/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 295.2677 - root_mean_squared_error: 1724.5671
# Epoch 00068: val_loss did not improve from 314.52050
# 65849/65849 [==============================] - 119s 2ms/sample - loss: 295.2227 - root_mean_squared_error: 1724.2573 - val_loss: 315.2440 - val_root_mean_squared_error: 3046.3567
# Epoch 69/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 295.2914 - root_mean_squared_error: 1723.2412
# Epoch 00069: val_loss did not improve from 314.52050
# 65849/65849 [==============================] - 118s 2ms/sample - loss: 295.2104 - root_mean_squared_error: 1722.9171 - val_loss: 314.8067 - val_root_mean_squared_error: 3047.3374
# Epoch 70/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 295.0435 - root_mean_squared_error: 1722.4558
# Epoch 00070: val_loss improved from 314.52050 to 314.37298, saving model to Checkpoint/rnn_90_90_1.h5
# 65849/65849 [==============================] - 119s 2ms/sample - loss: 295.2000 - root_mean_squared_error: 1722.6516 - val_loss: 314.3730 - val_root_mean_squared_error: 3048.2791
# Epoch 71/100
# 65792/65849 [============================>.] - ETA: 0s - loss: 295.1915 - root_mean_squared_error: 1723.6415
# Epoch 00071: val_loss did not improve from 314.37298
# 65849/65849 [==============================] - 117s 2ms/sample - loss: 295.0798 - root_mean_squared_error: 1722.9441 - val_loss: 315.0033 - val_root_mean_squared_error: 3048.8330
# Epoch 72/100
# 65792/65849 [============================>.] - ETA: 0s - loss: 294.9107 - root_mean_squared_error: 1723.3550
# Epoch 00072: val_loss improved from 314.37298 to 314.26125, saving model to Checkpoint/rnn_90_90_1.h5
# 65849/65849 [==============================] - 117s 2ms/sample - loss: 294.9489 - root_mean_squared_error: 1722.7998 - val_loss: 314.2613 - val_root_mean_squared_error: 3046.7366
# Epoch 73/100
# 65792/65849 [============================>.] - ETA: 0s - loss: 295.2204 - root_mean_squared_error: 1723.6561
# Epoch 00073: val_loss did not improve from 314.26125
# 65849/65849 [==============================] - 117s 2ms/sample - loss: 295.0671 - root_mean_squared_error: 1722.9244 - val_loss: 315.6597 - val_root_mean_squared_error: 3043.5659
# Epoch 74/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 295.0434 - root_mean_squared_error: 1721.6544
# Epoch 00074: val_loss did not improve from 314.26125
# 65849/65849 [==============================] - 119s 2ms/sample - loss: 294.9872 - root_mean_squared_error: 1721.3418 - val_loss: 315.1320 - val_root_mean_squared_error: 3045.0549
# Epoch 75/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 295.0360 - root_mean_squared_error: 1721.8197
# Epoch 00075: val_loss did not improve from 314.26125
# 65849/65849 [==============================] - 119s 2ms/sample - loss: 294.9632 - root_mean_squared_error: 1721.4985 - val_loss: 314.4780 - val_root_mean_squared_error: 3046.3247
# Epoch 76/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 294.9183 - root_mean_squared_error: 1721.5220
# Epoch 00076: val_loss did not improve from 314.26125
# 65849/65849 [==============================] - 118s 2ms/sample - loss: 294.8739 - root_mean_squared_error: 1721.2102 - val_loss: 314.8228 - val_root_mean_squared_error: 3045.4229
# Epoch 77/100
# 65824/65849 [============================>.] - ETA: 0s - loss: 294.8163 - root_mean_squared_error: 1721.9397
# Epoch 00077: val_loss did not improve from 314.26125
# 65849/65849 [==============================] - 118s 2ms/sample - loss: 294.8174 - root_mean_squared_error: 1721.6902 - val_loss: 315.3951 - val_root_mean_squared_error: 3042.9539

# %%
UPDATED_EPOCHS = 77 + 1

# %%
## 모델 성능 그래프로 나타내기

import numpy as np

epochs = np.arange(1, UPDATED_EPOCHS)
fig, axes = plt.subplots(figsize=(20, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs, history2.history['loss'], label='train_loss')
plt.plot(epochs, history2.history['val_loss'], label='val_loss')
plt.xlabel('epochs', fontdict={'size': 10})
plt.ylabel('loss', fontdict={'size': 10})
plt.title("MAE")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs, history2.history['root_mean_squared_error'], label='train_loss')
plt.plot(epochs, history2.history['val_root_mean_squared_error'], label='val_loss')
plt.xlabel('epochs', fontdict={'size': 10})
plt.ylabel('loss', fontdict={'size': 10})
plt.title("RMSE")
plt.legend()

plt.show()

# %%
# 모델 저장하고 복원하기
from tensorflow.keras.models import load_model

filename = 'rnn_{}_{}_{}.h5'.format(filter_size, target_size, stride)

model.save('Model/{}'.format(filename))
res_model = load_model('Model/{}'.format(filename))
res_model.load_weights('Model/{}'.format(filename))
#res_model.evaluate(x_test_copy, y_test_copy)
mae, rmse = model.evaluate(x_test_copy, y_test_copy, verbose=2)
print("MAE of Untrained Model: {:5.2f}%".format(mae))
print("RMSE of Untrained Model: {:5.2f}%".format(rmse))
# Out:
# 20579/1 - 9s - loss: 174.5915 - root_mean_squared_error: 2987.5500
# MAE of Untrained Model: 318.84%
# RMSE of Untrained Model: 2987.55%

# %%
mae
# Out:
# 318

# %%
# 테스트 세트로 예측하기
test_predict = model.predict(x_test_copy)

# %%
# 예측한 것 시각화하기 (한 개 다 합친 것)

actual = pd.DataFrame(y_test_copy[:,0,0], columns=['actual'])
pred = pd.DataFrame(test_predict[:,0], columns=['pred'])
result = pd.concat([actual, pred], axis=1)
ord_result = result.sort_values(by=['actual']) # 순차적으로
start, end = 7500, 8000
my_result = ord_result.iloc[start:end] # 보고 싶은 범위만

fig, axes = plt.subplots(figsize=(20, 15))

plt.subplot(3, 1, 1)
total = [j for j in range(y_test_copy.shape[0])]
plt.plot(total, result['actual'], 'r', label='actual')
plt.plot(total, result['pred'], 'b', label='predicted', alpha=0.7)
plt.title("All of the Test Datas")
plt.legend()

plt.subplot(3, 1, 2)
total = [j for j in range(ord_result.shape[0])]
plt.plot(total, ord_result['actual'], 'r', label='actual')
plt.plot(total, ord_result['pred'], 'b', label='predicted', alpha=0.7)
plt.title("All of the Test Datas (ordered)")
plt.legend()

plt.subplot(3, 1, 3)
total = [j for j in range(my_result.shape[0])]
plt.plot(total, my_result['actual'], 'r', label='actual')
plt.plot(total, my_result['pred'], 'b', label='predicted', alpha=0.7)
plt.title("Some Test Datas (ordered)")
plt.legend()

plt.show()

# %%
good_a, good_p, bad_a, bad_p = [], [], [], []
mae = int(mae)

for i in range(result.shape[0]):
    a = result['actual'].iloc[i]
    p = result['pred'].iloc[i]

    if abs(a-p) <= mae:
        good_a.append(a)
        good_p.append(p)
    else:
        bad_a.append(a)
        bad_p.append(p)

good_a = pd.DataFrame(good_a, columns=['actual'])
good_p = pd.DataFrame(good_p, columns=['pred'])
good_result = pd.concat([good_a, good_p], axis=1)
good_ord_result = good_result.sort_values(by=['actual']) # 순차적으로

bad_a = pd.DataFrame(bad_a, columns=['actual'])
bad_p = pd.DataFrame(bad_p, columns=['pred'])
bad_result = pd.concat([bad_a, bad_p], axis=1)
bad_ord_result = bad_result.sort_values(by=['actual']) # 순차적으로

print("total test samples:", result.shape[0], "개")
per_mae = np.round((good_result.shape[0]/result.shape[0])*100, 2)
print("good mae result / total result (%):", per_mae)

fig, axes = plt.subplots(figsize=(20, 20)) # Test MAE보다 작거나 같은 것만

plt.subplot(4, 1, 1)
total = [j for j in range(good_result.shape[0])]
plt.plot(total, good_result['actual'], 'r', label='actual')
plt.plot(total, good_result['pred'], 'b', label='predicted', alpha=0.7)
plt.legend()
plt.title("Good Predictions (error less than MAE {}".format(mae)+ ")")

plt.subplot(4, 1, 2)
total = [j for j in range(good_ord_result.shape[0])]
plt.plot(total, good_ord_result['actual'], 'r', label='actual')
plt.plot(total, good_ord_result['pred'], 'b', label='predicted', alpha=0.7)
plt.legend()
plt.title("Good Predictions (error less than MAE {}".format(mae)+ ") (ordered)")

plt.subplot(4, 1, 3)
total = [j for j in range(bad_result.shape[0])]
plt.plot(total, bad_result['actual'], 'r', label='actual')
plt.plot(total, bad_result['pred'], 'b', label='predicted', alpha=0.7)
plt.legend()
plt.title("Bad Predictions (error more than MAE {}".format(mae)+ ")")

plt.subplot(4, 1, 4)
total = [j for j in range(bad_ord_result.shape[0])]
plt.plot(total, bad_ord_result['actual'], 'r', label='actual')
plt.plot(total, bad_ord_result['pred'], 'b', label='predicted', alpha=0.7)
plt.legend()
plt.title("Bad Predictions (error ore than MAE {}".format(mae)+ ") (ordered)")

plt.show()
# Out:
# total test samples: 20579 개
# good mae result / total result (%): 84.06

# %%
start = 10000
end = 20000

column_classes = X.columns.unique().tolist()
channel = pd.DataFrame(scaler.transform(X.loc[start:end, :]), columns=X.columns)
channel_list = channel.values.reshape(channel.shape[0], -1, filter_size) # (end-start, features, filters)

channel_real = y.loc[start:end, :].values.flatten() # (end-start, 1)
channel_pred = model.predict(channel_list).flatten() # (end-start, 1)
pred = pd.DataFrame(dict(real=channel_real, pred=channel_pred))

# %%
import seaborn as sns

plt.figure(figsize=(15, 5))
to_plot = pred.melt()
to_plot['ticks'] = [i for i in range(pred.shape[0])] * 2
sns.lineplot(x='ticks', y='value', hue='variable', data=to_plot)
plt.title('Prediction for One Channel')
plt.show()
